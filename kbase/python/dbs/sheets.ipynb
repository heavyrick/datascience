# %% [markdown]
# # Planilhas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/copacabana.csv', delimiter=';')

# %%
df.head()
# Out:
#    Posicao  Quartos  Vagas  DistIpanema  DistPraia  DistFavela  RendaMedia  \
# 0        1      3.0   0.01         1144        311         146      969501
# 1        0      2.0   0.01         2456        502         254     1472861
# 2        0      2.0   0.01         2448        772         229     1803724
# 3        0      2.0   0.01         1615        428         310     1124331
# 4        0      2.0   1.00         2358        586         287     1165764
#
#    RendaMovel  RendaMovelRua  Vu2009  Mes  Idade  Tipologia  AreaConstruida  \
# 0     1028834         999168    1750  509   37.0          1              95
# 1     1137759        1305310    2300  484   30.0          1              71
# 2     1512475        1658100    2350  920   44.0          1              58
# 3     1370600        1247466    2200  930   43.0          1              88
# 4     1177933        1171849    2150  918   42.0          1              68
#
#    VAL_UNIT            X            Y
# ...

# %%
df.columns #colunas
# Out:
# Index(['Posicao', 'Quartos', 'Vagas', 'DistIpanema', 'DistPraia', 'DistFavela',
#        'RendaMedia', 'RendaMovel', 'RendaMovelRua', 'Vu2009', 'Mes', 'Idade',
#        'Tipologia', 'AreaConstruida', 'VAL_UNIT', 'X', 'Y'],
#       dtype='object')

# %%
df['Quartos'].describe()
# Out:
# count    1675.000000
# mean        1.767510
# std         1.142523
# min         0.010000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         6.000000
# Name: Quartos, dtype: float64

# %%
df['Quartos'] > 5 # Quartos com quantidade maior que 5
df.loc[df['Quartos'] == 6] # linhas cuja quantidade de quartos é igual a 6
# Out:
#      Posicao  Quartos  Vagas  DistIpanema  DistPraia  DistFavela  RendaMedia  \
# 748        1      6.0    2.0         2500         35         743     1524600
#
#      RendaMovel  RendaMovelRua  Vu2009  Mes  Idade  Tipologia  AreaConstruida  \
# 748     1275377        1399989    4100  360   58.0          1             668
#
#      VAL_UNIT          X           Y
# 748      4491  686456.25  7458801.05

# %%
df.loc[df['Quartos'] == 5] # linhas cuja quantidade de quartos é igual a 5
# Out:
#       Posicao  Quartos  Vagas  DistIpanema  DistPraia  DistFavela  RendaMedia  \
# 173         1      5.0   0.01         2696        154         712     1083455
# 1521        1      5.0   3.00         3044         31         609     1524600
#
#       RendaMovel  RendaMovelRua  Vu2009  Mes  Idade  Tipologia  \
# 173       649733         866594    2000  425   55.0          1
# 1521     1168222        1346411    4100  405   34.0          1
#
#       AreaConstruida  VAL_UNIT            X           Y
# 173               38      6316  686522.9800  7458989.87
# 1521             430      5000  686965.3201  7459109.71

# %%
df.loc[df['Idade'].max()] # linha do valor máximo da idade
# Out:
# Posicao                 1.00
# Quartos                 0.01
# Vagas                   0.01
# DistIpanema          1679.00
# DistPraia             440.00
# DistFavela            325.00
# RendaMedia        1124331.00
# RendaMovel        1102941.00
# RendaMovelRua     1113636.00
# Vu2009               2200.00
# Mes                   567.00
# Idade                  60.00
# Tipologia               1.00
# AreaConstruida         34.00
# VAL_UNIT             5294.00
# X                  685459.12
# Y                 7458329.39
# Name: 75, dtype: float64

# %%
# Criar coluna TOTAL, recebendo uma multiplicação
df['TOTAL'] = df['AreaConstruida'] * df['VAL_UNIT']
df['TOTAL'].describe()
# Out:
# count    1.675000e+03
# mean     5.862613e+05
# std      4.804788e+05
# min      6.000000e+04
# 25%      3.000000e+05
# 50%      4.500320e+05
# 75%      7.200115e+05
# max      6.199912e+06
# Name: TOTAL, dtype: float64

# %% [markdown]
# ### Saída de dados em CSV

# %%
df.to_csv('data/saida_exemplo.csv',index=False)

# %% [markdown]
# ## Excel
#
# Pandas podem ler e escrever arquivos do Excel, tenha em mente, isso só importa dados. Não fórmulas nem imagens, lembrando que imagens ou macros podem bugar o método.

# %%
pd.read_excel('data/exemplo_excel.xlsx',sheetname='Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %% [markdown]
# ### Saída via Excel

# %%
df.to_excel('data/saida_exemplo_excel.xlsx',sheet_name='Sheet1')

# %% [markdown]
# ## HTML
#
# Você pode precisar instalar htmllib5, lxml e BeautifulSoup4. No seu terminal / prompt de comando, execute:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Em seguida, reinicie o Jupyter Notebook.
# (Ou use instalação de pip se não estiver usando a Distribuição de Anaconda)
# Pandas podem ler guias de tabelas fora de html. Por exemplo:

# %% [markdown]
# ### Entrada HTML
#
# A função Pandas read_html irá ler tabelas fora de uma página da Web e retornar uma lista de objetos DataFrame:

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df[0].head(20)
# Out:
#                                             Bank Name                City  ST  \
# 0                                The Enloe State Bank              Cooper  TX
# 1                 Washington Federal Bank for Savings             Chicago  IL
# 2     The Farmers and Merchants State Bank of Argonia             Argonia  KS
# 3                                 Fayette County Bank          Saint Elmo  IL
# 4   Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 5                                      First NBC Bank         New Orleans  LA
# 6                                       Proficio Bank  Cottonwood Heights  UT
# 7                       Seaway Bank and Trust Company             Chicago  IL
# 8                              Harvest Community Bank          Pennsville  NJ
# 9                                         Allied Bank            Mulberry  AR
# 10                       The Woodbury Banking Company            Woodbury  GA
# ...
